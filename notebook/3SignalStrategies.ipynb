# %% [markdown]
# # Notebook 1: FX Equity Model Signal Strategies

# %% [markdown]
# The overall goal of this strategy is to link the equity returns differential FX futures. The main approach is to find which equities outperform US equities and then trade FX Futures. The idea is that there is a relationship between equity returns differential of a foreign country and its currency.

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
from   scipy.stats import ttest_1samp

import matplotlib.pyplot as plt
from   matplotlib.ticker import FuncFormatter

import statsmodels.api as sm
from   statsmodels.regression.rolling import RollingOLS

# %% [markdown]
# # Getting Data

# %% [markdown]
# To calculate the equity returns differential the MSCI ETFs total return prices are used, then calculate the price returns, and take the difference.

# %%
eq_path    = os.path.join("OldDATA", "ETFPX_old.parquet")
fut_path   = os.path.join("OldDATA", "FutPX.parquet")
guide_path = os.path.join("OldDATA", "FXTickerGuide.xlsx")

# %%
repo_path = os.getcwd()
data_path = os.path.join(repo_path, "data")
raw_path  = os.path.join(data_path, "RawData")

# %% [markdown]
#     .pct_change()
#     .reset_index()
#     .melt(id_vars = ["SPY", "date"])
#     .dropna()
#     .assign(spread = lambda x: x.value - x.SPY)

# %%
eq_path      = os.path.join(raw_path, "EquityPX.parquet")
df_eq_spread = (pd
    .read_parquet(path = eq_path)
    .loc[lambda x: x.px_type == "Adj Close"]
    .pivot(index = "date", columns = "ticker", values = "value")
    .pct_change()
    .reset_index()
    .melt(id_vars = ["SPY", "date"])
    .dropna()
    .assign(spread = lambda x: x.value - x.SPY))

# %% [markdown]
# Then calculate the 30d Exponentially weighted z-score of the equity returns differential.

# %%
window    = 30
df_signal = (df_eq_spread
    .pivot(index = "date", columns = "ticker", values = "spread")
    .apply(lambda x: (x - x.ewm(span = window, adjust = False).mean()) / x.ewm(span = window, adjust = False).std())
    .shift()
    .reset_index()
    .melt(id_vars = "date", var_name = "etf_ticker", value_name = "signal")
    .dropna())

# %%
fut_path = os.path.join(data_path, "RawData", "FutPX.parquet")

# %%
df_fut_rtn = (pd
    .read_parquet(path = fut_path)
    .assign(security = lambda x: x.security.str.split("1").str[0])
    .pivot(index = "date", columns = "security", values = "PX_LAST")
    .pct_change()
    .reset_index()
    .melt(id_vars = "date", value_name = "fut_rtn")
    .dropna())

# %%
guide_path = os.path.join(data_path, "FXTickerGuide.xlsx")

# %%
df_ticker_guide = (pd
    .read_excel(io = guide_path, sheet_name = "TickerGuide")
    .loc[lambda x: x.group == "liquid_future"]
    [["ticker", "etf_ticker", "country", "name"]]
    .rename(columns = {"ticker": "fut_ticker"}))

# %%
df_combined = (df_fut_rtn
    .rename(columns = {"security": "fut_ticker"})
    .assign(date = lambda x: pd.to_datetime(x.date).dt.date)
    .merge(right = df_ticker_guide, how = "inner", on = ["fut_ticker"])
    .merge(right = df_signal, how = "inner", on = ["date", "etf_ticker"]))

# %% [markdown]
# # Analyzing signal

# %%
avg_corr = (df_eq_spread
    .pivot(index = "date", columns = "ticker", values = "value")
    .corr()
    .to_numpy()
    .ravel()
    .mean())

spread_corr = (df_eq_spread
    .pivot(index = "date", columns = "ticker", values = "spread")
    .corr()
    .to_numpy()
    .ravel()
    .mean())

zscore_corr = (df_signal.pivot(
    index = "date", columns = "etf_ticker", values = "signal").
    corr().
    to_numpy().
    ravel().
    mean())

# %%
fig, axes = plt.subplots(figsize = (8,5))

(pd.DataFrame({
    "signal": ["Raw Returns", "Returns\nSpread", "Z-Score\nReturns Spread"],
    "value" : [avg_corr, spread_corr, zscore_corr]}).
    set_index("signal").
    plot(
        ax     = axes,
        kind   = "bar",
        rot    = 0,
        xlabel = "",
        legend = False,
        ylabel = "Average Pairwise Correlation",
        title  = "Average Pairwise Correlation across signal"))

axes.yaxis.set_major_formatter(formatter = FuncFormatter(lambda x, pos: f"{x:.0%}"))

# %% [markdown]
# The return differential may be strongly correlated with the underlying equity trend. To investigate this, compute the pairwise correlations between the signal (as well as its z-score) and a generic trend-following signal. To calculate trend a simple EWMA was used as described in Bouchaud et al. (2017): https://papers.ssrn.com/sol3/papers.cfm?abstract_id=2777657

# %%
df_eq_dt = (pd
    .read_parquet(path = eq_path, engine = "pyarrow")
    .loc[lambda x: x.px_type == "Adj Close"]
    .assign(date = lambda x: pd.to_datetime(x.date).dt.date)
    .pivot(index = "date", columns = "ticker", values = "value")
    .diff()
    .apply(lambda x: x / x.ewm(span = 10, adjust = False).std()))

df_fx_dt = (pd.read_parquet(
    path = fut_path).
    assign(
        date     = lambda x: pd.to_datetime(x.date).dt.date,
        security = lambda x: x.security.str.split("1").str[0]).
    rename(columns = {"security": "ticker"}).
    pivot(index = "date", columns = "ticker", values = "PX_LAST").
    diff().
    apply(lambda x: x / x.ewm(span = 10, adjust = False).std()))

# %%
def _get_trend(df: pd.DataFrame, window: int = 5) -> pd.DataFrame: 

    df_out = (df.apply(
        lambda x: x.ewm(span = window, adjust = False).mean().shift()).
        reset_index().
        melt(id_vars = "date", value_name = "signal").
        dropna().
        assign(window = window))

    return df_out

df_eq_trend = pd.concat([_get_trend(df_eq_dt, window) for window in [5, 30, 100]])
df_fx_trend = pd.concat([_get_trend(df_fx_dt, window) for window in [5, 30, 100]])
df_trend    = pd.concat([
    df_eq_trend.assign(asset_class = "eq"), 
    df_fx_trend.assign(asset_class = "fx")])

# %%
replacer = (df_ticker_guide.set_index(
    "fut_ticker").
    etf_ticker.
    to_dict())

# %%
keep_tickers = list(replacer.keys()) + df_eq_dt.columns.to_list()

# %%
df_eq_tmp = (df_eq_spread.pivot(
    index = "date", columns = "ticker", values = "spread").
    shift().
    reset_index().
    melt(id_vars = "date", var_name = "ticker", value_name = "eq_spread").
    dropna())

# %%
(df_trend
    .replace(replacer)
    .loc[lambda x: x.ticker.isin(keep_tickers)]
    .assign(date = lambda x: pd.to_datetime(x.date).dt.date)
    .rename(columns = {"signal": "trend_signal"})
    .assign(date = lambda x: pd.to_datetime(x.date))
    .merge(right = df_eq_tmp, how = "inner", on = ["date", "ticker"])
    .rename(columns = {"ticker": "etf_ticker"})
    .merge(right = df_signal, how = "inner", on = ["date", "etf_ticker"])
    .melt(id_vars = ["date", "etf_ticker", "trend_signal", "window", "asset_class"])
    .drop(columns = ["date"])
    .groupby(["etf_ticker", "window", "asset_class", "variable"])
    .agg("corr")
    .reset_index()
    .loc[lambda x: x.value != 1])

# %%
(df_trend
    .replace(replacer)
    .loc[lambda x: x.ticker.isin(keep_tickers)]
    .assign(date = lambda x: pd.to_datetime(x.date).dt.date)
    .rename(columns = {"signal": "trend_signal"})
    .assign(date = lambda x: pd.to_datetime(x.date))
    .merge(right = df_eq_tmp, how = "inner", on = ["date", "ticker"])
    .rename(columns = {"ticker": "etf_ticker"})
    .merge(right = df_signal, how = "inner", on = ["date", "etf_ticker"])
    .melt(id_vars = ["date", "etf_ticker", "trend_signal", "window", "asset_class"])
    .drop(columns = ["date"])
    .groupby(["etf_ticker", "window", "asset_class", "variable"])
    .agg("corr")
    .reset_index()
    .loc[lambda x: x.value != 1]
    .assign(etf_ticker = lambda x: x.etf_ticker + " US Equity")
    .merge(right = df_ticker_guide, how = "inner", on = ["etf_ticker"])
    .rename(columns = {
        "country"    : "Country/Region",
        "variable"   : "",
        "asset_class": "Asset Class",
        "window"     : "lookback"})
    .replace({
        "eq_spread": "Eq. Rtn Spread",
        "signal"   : "30d Z-Score",
        "eq"       : "Equity",
        "fx"       : "FX"})
    .pivot(index = ["Country/Region"], columns = ["Asset Class", "lookback", ""], values = "value")
    .apply(lambda x: np.round(x,3)))

# %%
df_combined = (df_fut_rtn
    .pivot(index = "date", columns = "security", values = "fut_rtn")
    .apply(lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std() * np.sqrt(252))))
    .reset_index()
    .melt(id_vars = ["date"], value_name = "vol_rtn")
    .dropna()
    .merge(right = df_fut_rtn, how = "inner", on = ["date", "security"])
    .rename(columns = {"security": "fut_ticker"})
    .assign(fut_ticker = lambda x: x.fut_ticker + "1 Curncy")
    .merge(right  = df_ticker_guide, how = "inner", on = ["fut_ticker"])
    .assign(
        date       = lambda x: pd.to_datetime(x.date),
        etf_ticker = lambda x: x.etf_ticker.str.split(" ").str[0])
    .merge(right = df_signal, how = "inner", on = ["date", "etf_ticker"]))

# %%
fig, axes = plt.subplots(figsize = (10,5))


(df_combined
    [["date", "name", "signal", "vol_rtn", "fut_rtn"]]
    .melt(id_vars = ["date", "name", "signal"])
    .drop(columns = ["date"])
    .groupby(["name", "variable"])
    .agg("corr")
    .reset_index()
    .loc[lambda x: x.value != 1]
    .rename(columns = {"variable": ""})
    .replace({
        "fut_rtn": "Raw Rtn",
        "vol_rtn": "Target Rtn"})
    .assign(name = lambda x: x.name.str.replace("Future", "").str.strip().str.replace(" ", "\n").str.replace("New\nZealand", "New Zealand"))
    .pivot(index = "name", columns = "", values = "value")
    .sort_values("Raw Rtn")
    .plot(
        ax     = axes,
        kind   = "bar",
        ylabel = "Pairwise Correlation of lagged\nEquity Returns - SPY (%)",
        xlabel = "",
        rot    = 0,
        title  = "Comparing Correlation of Lagged Equity Returns Differential vs. FX Futures Return\nRaw and 10% Volatility Targeted (Contemporaneously)"))

axes.yaxis.set_major_formatter(FuncFormatter(lambda x, pos: f"{x:.0%}"))
#out_path = os.path.join("new_latex", "pictures", "SignalReturnsCorrelation.png")
#fig.savefig(out_path, dpi = 300)

# %%
def _get_corr(df: pd.DataFrame, window: int = 30) -> pd.DataFrame:

    df_out = (df
        .assign(roll_corr = lambda x: x.signal.rolling(window = window).corr(x.value))
        .dropna())

    return df_out

window       = 90
df_roll_corr = (df_combined
    .drop(columns = ["name", "country", "fut_ticker"])
    .melt(id_vars = ["date", "etf_ticker", "signal"])
    .assign(group_var = lambda x: x.etf_ticker + "-" + x.variable)
    .set_index("date")
    .groupby("group_var")
    .apply(_get_corr, window)
    .reset_index())

# %%
variable_renamer = {
    "fut_rtn": "Futures Return",
    "vol_rtn": "10% Volatility Targeted Returns (Contemporaneously)"}

# %%
variables = df_roll_corr.variable.drop_duplicates().sort_values().to_list()
fig, axes = plt.subplots(ncols = len(variables), figsize = (20,6))

variable_renamer = {
    "fut_rtn": "Futures Return",
    "vol_rtn": "10% Volatility Targeted Returns (Contemporaneously)"}

for variable, ax in zip(variables, axes.flatten()):

    (df_roll_corr
        .loc[lambda x: x.variable == variable]
        .pivot(index = "date", columns = "etf_ticker", values = "roll_corr")
        .plot(
            ax     = ax,
            legend = False,
            alpha  = 0.6,
            ylabel = "Lagged Equity Differential 90d Correlation\nto FX Return",
            title  = variable_renamer[variable]))

    ax.yaxis.set_major_formatter(FuncFormatter(lambda x, pos: f"{x:.0%}"))

fig.suptitle("Lagged Equity Differential 90d Correlation to FX Return")
plt.tight_layout()

# %% [markdown]
# # Trading Raw Z-Score

# %% [markdown]
# Start by computing a 30-day exponentially weighted z-score of the daily foreign–domestic equity return differential. This z-score is then used as a trading signal, which is scaled to target an annualized volatility of 10\% through daily rebalancing.

# %% [markdown]
# Two approaches to volatility targeting are considered: a “perfect foresight” (contemporaneous) volatility scaling and a lagged volatility targeting scheme. While the lagged specification is the correct implementable approach, the higher-frequency (daily) nature of the data implies that sharp intraday volatility spikes can lead to material losses before risk adjustments take effect.

# %% [markdown]
# In practice, however, an investor or broker would likely adjust positions intraday in response to extreme market moves, mitigating some of this effect. Such discontinuities are more prevalent in commodities than in currencies, but the exercise remains informative as it quantifies the Sharpe ratio cost of not incorporating intraday volatility management.

# %%
df_zscore_rtn = (df_combined.assign(
    signal_rtn = lambda x: np.sign(x.signal) * x.fut_rtn).
    pivot(index = "date", columns = "fut_ticker", values = "signal_rtn"))

# %%
df_lagged = (df_zscore_rtn.apply(
    lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std().shift() * np.sqrt(252)))).
    reset_index().
    melt(id_vars = "date", value_name = "rtn").
    dropna().
    assign(group = "lagged"))

df_perf = (df_zscore_rtn.apply(
    lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std() * np.sqrt(252)))).
    reset_index().
    melt(id_vars = "date", value_name = "rtn").
    dropna().
    assign(group = "perf"))

df_raw_zscore_combined = pd.concat([df_lagged, df_perf])

# %% [markdown]
# The results from trading FX futures are presented below. While the performance is not particularly strong, the returns appear to be relatively stable over time. This suggests that there may be some scope for further refinement and data-driven optimization of the signal.

# %%
group_vars = df_raw_zscore_combined.group.drop_duplicates().sort_values().to_list()
fig, axes  = plt.subplots(ncols = len(group_vars), figsize = (20,6))

for group_var, ax in zip(group_vars, axes.flatten()): 

    (df_raw_zscore_combined
        .loc[lambda x: x.group == group_var]
        .rename(columns = {"fut_ticker": ""})
        .pivot(index = "date", columns = "", values = "rtn")
        .apply(lambda x: np.cumprod(1 + x))
        .plot(
            ax     = ax,
            logy   = True,
            ylabel = "Cuml. Ret. Log-Scaled",
            title  = group_var.capitalize() + " Volatility Targeting"))

fig.suptitle("Cumulative Returns of Trading Equity Return Differentials Amongst Currency Futures\n10% Volatility Targeting From {} to {}".format(
    df_combined.date.min(),
    df_combined.date.max()))
plt.tight_layout()

# %% [markdown]
# Below are the sharpes per each future contract. While the results are not strong the consistency of the returns implores further analysis, that a model can be fit.

# %%
display(df_raw_zscore_combined.drop(
    columns = ["date"]).
    groupby(["fut_ticker", "group"]).
    agg(lambda x: x.mean() / x.std() * np.sqrt(252)).
    reset_index().
    rename(columns = {
        "group"     : "",
        "fut_ticker": "Fut Ticker"}).
    replace({
        "lagged": "Lagged Vol",
        "perf"  : "Perfect Vol"}).
    pivot(index = "", columns = "Fut Ticker", values = "rtn").
    apply(lambda x: np.round(x,3)))

# %% [markdown]
# # Trading Z-Score Deciles

# %% [markdown]
# Start by calculating decile bins for the z-score and then calculating the sharpe per each bin. Then examine the outerbins 1st, 2nd, 9th, and 10th. To trade just ensure that the each upper or lower set of sharpe bins have a sharpe of the same sign.

# %%
df_decile = (df_eq_spread.pivot(
    index = "date", columns = "ticker", values = "spread").
    apply(lambda x: (x - x.ewm(span = window, adjust = False).mean()) / x.ewm(span = window, adjust = False).std()).
    apply(lambda x: pd.qcut(x = x, q = 10, labels = [i + 1 for i in range(10)])).
    shift().
    reset_index().
    melt(id_vars = "date", var_name = "etf_ticker", value_name = "decile").
    dropna())

# %% [markdown]
# df_decile_prep = (df_fut_rtn.rename(
#     columns = {"security": "fut_ticker"}).
#     assign(date = lambda x: pd.to_datetime(x.date).dt.date).
#     merge(right = df_ticker_guide, how = "inner", on = ["fut_ticker"]).
#     merge(right = df_decile, how = "inner", on = ["date", "etf_ticker"]))

# %%
df_decile_prep = (df_fut_rtn
    .rename(columns = {"security": "fut_ticker"})
    .assign(
        date       = lambda x: pd.to_datetime(x.date),
        fut_ticker = lambda x: x.fut_ticker + "1 Curncy")
    .merge(right = df_ticker_guide, how = "inner", on = ["fut_ticker"])
    .assign(etf_ticker = lambda x: x.etf_ticker.str.split(" ").str[0])
    .merge(right = df_decile, how = "inner", on = ["date", "etf_ticker"]))

# %%
df_decile_sharpe = (df_decile_prep
    .drop(columns = ["date", "name", "etf_ticker", "country"])
    .groupby(["fut_ticker", "decile"])
    .agg(lambda x: x.mean() / x.std() * np.sqrt(252))
    .reset_index()
    .rename(columns = {"fut_rtn": "sharpe"}))

# %%
tickers = df_decile_sharpe.fut_ticker.drop_duplicates().sort_values().to_list()
fig, axes = plt.subplots(ncols = 3, nrows = 3, figsize = (20,10))

for ticker, ax in zip(tickers, axes.flatten()):

    (df_decile_sharpe.query(
        "fut_ticker == @ticker").
        set_index("decile")
        [["sharpe"]].
        plot(
            kind   = "bar", 
            ax     = ax,
            legend = False,
            rot    = 0,
            xlabel = "",
            ylabel = "Ann. Sharpe",
            title  = ticker))

fig.suptitle("Sharpe per bins of 30d Z-Score for each FX Group")
plt.tight_layout()

# %%
df_decile_tmp = (df_decile_sharpe.query(
    "decile == [1,2,9,10]").
    assign(group = lambda x: np.where(x.decile <= 2, "lower_group", "upper_group")))

# %%
df_signal_raw_rtn = (df_decile_tmp.drop(
    columns = ["decile"]).
    groupby(["fut_ticker", "group"]).
    agg("prod").
    reset_index().
    assign(signal_scaler = lambda x: np.where(x.sharpe > 0.1, 1, np.nan)).
    drop(columns = ["sharpe"]).
    merge(right = df_decile_tmp, how = "outer", on = ["fut_ticker", "group"]).
    merge(right = df_decile_prep, how = "outer", on = ["fut_ticker", "decile"]).
    assign(signal_rtn = lambda x: np.sign(x.signal_scaler * x.sharpe) * x.fut_rtn))

# %%
df_sig_wider = (df_signal_raw_rtn.pivot(
    index = "date", columns = "fut_ticker", values = "signal_rtn"))

# %%
df_lagged = (df_sig_wider.apply(
    lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std().shift() * np.sqrt(252)))).
    apply(lambda x: np.where(np.abs(x) == np.inf, np.nan, x)).
    reset_index().
    melt(id_vars = "date", value_name = "rtn").
    dropna().
    assign(vol_group = "lagged"))

df_perf = (df_sig_wider.apply(
    lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std() * np.sqrt(252)))).
    apply(lambda x: np.where(np.abs(x) == np.inf, np.nan, x)).
    reset_index().
    melt(id_vars = "date", value_name = "rtn").
    dropna().
    assign(vol_group = "perfect"))

# %%
df_sig_rtn = (pd.concat([
    df_lagged, df_perf]))

# %% [markdown]
# Then to backtest the strategy set a 10% volatility target.

# %%
group_vars = df_sig_rtn.vol_group.drop_duplicates().sort_values().to_list()
fig, axes  = plt.subplots(ncols = len(group_vars), figsize = (20,5))

for group_var, ax in zip(group_vars, axes.flatten()): 

    (df_sig_rtn.query(
        "vol_group == @group_var").
        rename(columns = {"fut_ticker": ""}).
        pivot(index = "date", columns = "", values = "rtn").
        fillna(0).
        apply(lambda x: np.cumprod(1 + x)).
        plot(
            logy   = True,
            ax     = ax,
            title  = group_var.capitalize() + " Volatility Targeting",
            ylabel = "Cuml. Ret. Log-Scaled"))

fig.suptitle("Cumulative Returns of Trading FX Futures based on Deciles\n10% Volatility Targeting From {} to {}".format(
    df_sig_rtn.date.min().year,
    df_sig_rtn.date.max().year))

plt.tight_layout()

# %%
def _get_pvalue(df: pd.DataFrame, colname: str):

    t_stat, p_value = ttest_1samp(a = df[colname], popmean = 0)
    
    df_out = (pd.DataFrame.from_dict(
        data = {
            "t_stat" : t_stat,
            "p_value": p_value},
        orient = "index").
        rename(columns = {0: "value"}))

    return df_out

# %%
df_rtn_pvalue = (df_sig_rtn.assign(
    tmp = lambda x: x.fut_ticker + " " + x.vol_group).
    groupby("tmp").
    apply(_get_pvalue, "rtn").
    reset_index())

display(df_rtn_pvalue
    .assign(
        tmp    = lambda x: x.tmp.str.replace(" Curncy", ""),
        future = lambda x: x.tmp.str.split(" ").str[0],
        target = lambda x: x.tmp.str.split(" ").str[1])
    .rename(columns = {
        "level_1": ""})
    .pivot(index = ["future", "target"], columns = "", values = "value")
    .rename(columns = {
        "p_value": r"$p$-value",
        "t_stat" : r"$t$-stat"}))

# %%
(df_sig_rtn.drop(
    columns = ["date"]).
    groupby(["fut_ticker", "vol_group"]).
    agg(lambda x: x.mean() / x.std() * np.sqrt(252)).
    reset_index().
    assign(vol_group = lambda x: x.vol_group.str.capitalize()).
    rename(columns = {
        "vol_group" : "Vol Target",
        "fut_ticker": ""}).
    pivot(index = "", columns = "Vol Target", values = "rtn").
    apply(lambda x: np.round(x,3)))

# %%
group_vars = df_sig_rtn.vol_group.drop_duplicates().sort_values().to_list()
fig, axes  = plt.subplots(ncols = len(group_vars), figsize = (16,6))

for group_var, ax in zip(group_vars, axes.flatten()): 

    df_corr = (df_sig_rtn
        .loc[lambda x: x.vol_group == group_var]
        .rename(columns = {"fut_ticker": ""})
        .pivot(index = "date", columns = "", values = "rtn")
        .corr()
        .apply(lambda x: np.round(x,3)))

    (sns.heatmap(
        data  = df_corr,
        ax    = ax,
        cbar  = False,
        annot = True))

    ax.set_title(group_var.capitalize() + " Volatility Target")

fig.suptitle("Correlation across Deciled-Optimized Z-Score Strategies")
plt.tight_layout()

# %%
display(df_sig_rtn.rename(
    columns = {"rtn": "raw_rtn"}).
    assign(adj_rtn = lambda x: np.where(x.raw_rtn == 0, np.nan, x.raw_rtn)).
    melt(id_vars = ["date", "fut_ticker", "vol_group"]).
    dropna().
    drop(columns = ["date"]).
    groupby(["fut_ticker", "vol_group", "variable"]).
    agg(lambda x: x.mean() / x.std() * np.sqrt(252)).
    reset_index().
    rename(columns = {
        "vol_group" : "Vol Target",
        "variable"  : "",
        "fut_ticker": "Fut"}).
    replace({
        "adj_rtn": "Adj Sharpe",
        "raw_rtn": "Raw Sharpe",
        "lagged" : "Lagged",
        "perfect": "Perfect"}).
    pivot(index = "Fut", columns = ["Vol Target", ""], values = "value").
    apply(lambda x: np.round(x,3)))

# %%
df_zscore_port = (df_sig_rtn.drop(
    columns = ["fut_ticker"]).
    query("rtn != 0").
    groupby(["date", "vol_group"]).
    agg("mean").
    reset_index())

# %%
fig, axes = plt.subplots(figsize = (7,5))

(df_zscore_port.assign(
    vol_group = lambda x: x.vol_group.str.capitalize()).
    rename(columns = {"vol_group": ""}).
    pivot(index = "date", columns = "", values = "rtn").
    apply(lambda x: np.cumprod(1 + x)).
    plot(
        ax      = axes,
        logy    = True,
        ylabel  = "Cuml. Ret. Log-Scaled",
        title   = "Cumulative Returns of Trading Combined Portfolio of FX Futures\n10% Volatility Target from {} to {}".format(
            df_zscore_port.date.min().year,
            df_zscore_port.date.max().year)))

plt.tight_layout()

# %%
display(df_zscore_port.rename(columns = {
    "rtn": "raw_rtn"}).
    assign(adj_rtn = lambda x: np.where(x.raw_rtn != 0, x.raw_rtn, np.nan)).
    melt(id_vars = ["date", "vol_group"]).
    drop(columns = ["date"]).
    groupby(["vol_group", "variable"]).
    agg(lambda x: x.mean() / x.std() * np.sqrt(252)).
    reset_index().
    assign(vol_group = lambda x: x.vol_group.str.capitalize()).
    rename(columns = {
        "vol_group": "Vol Target",
        "variable" : ""}).
    pivot(index = "Vol Target", columns = "", values = "value").
    rename(columns = {
        "adj_rtn": "Adj Sharpe",
        "raw_rtn": "Raw Sharpe"}).
    apply(lambda x: np.round(x,3)))

# %% [markdown]
# # Trading Residuals of Z-Score

# %% [markdown]
# For this strategy run a regressin of the z-score against the returns the main approach is to run
# \begin{equation}
# r_t = \alpha + \beta \cdot z_t + \epsilon
# \end{equation}

# %%
df_vol_rtn = (df_fut_rtn
    .pivot(index = "date", columns = "security", values = "fut_rtn")
    .apply(lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std() * np.sqrt(252))))
    .reset_index()
    .melt(id_vars = "date", value_name = "fut_rtn")
    .dropna()
    .assign(group = "vol_target"))

# %%
df_combined = (pd
    .concat([df_vol_rtn, df_fut_rtn.assign(group = "no_target")])
    .rename(columns = {"security": "fut_ticker"})
    .assign(
        date       = lambda x: pd.to_datetime(x.date),
        fut_ticker = lambda x: x.fut_ticker + "1 Curncy")
    .merge(right = df_ticker_guide, how = "inner", on = ["fut_ticker"])
    .assign(etf_ticker = lambda x: x.etf_ticker.str.split(" ").str[0])
    .merge(right = df_signal, how = "inner", on = ["date", "etf_ticker"])
    .assign(group_var = lambda x: x.fut_ticker + " " + x.group))

# %%
def _get_params(df: pd.DataFrame) -> pd.DataFrame:

    model = (sm.OLS(
        endog = df.fut_rtn,
        exog  = sm.add_constant(df.signal)).
        fit())

    df_params  = model.params.to_frame(name = "param_val").reset_index()
    df_pvalues = model.pvalues.to_frame(name = "p_value").reset_index()
    df_tstats  = model.tvalues.to_frame(name = "t_stat").reset_index()

    df_out = (df_params.merge(
        right = df_pvalues, how = "inner", on = ["index"]).
        merge(right = df_tstats, how = "inner", on = ["index"]))

    return df_out

(df_combined
    .groupby("group_var")
    .apply(_get_params)
    .reset_index()
    .drop(columns = ["level_1"])
    .rename(columns = {"index": "param"})
    .melt(id_vars = ["group_var", "param"])
    .assign(
        group_var = lambda x: x.group_var.str.replace(" Curncy", ""),
        ticker    = lambda x: x.group_var.str.split(" ").str[0],
        target    = lambda x: x.group_var.str.split(" ").str[1])
    .rename(columns = {
        "variable": "",
        "param"   : "Param",
        "ticker"  : "Ticker",
        "target"  : "Target"})
    .replace({
        "no_target" : "No Target",
        "param_val" : "Param Val",
        "p_value"   : r"$p$-value",
        "t_stat"    : r"$t$-stat",
        "vol_target": "Vol Target",
        "const"     : r"$\alpha$",
        "signal"    : "Z-Score"})
    .pivot(index = ["Ticker", "Target"], columns = ["", "Param"], values = "value").
    apply(lambda x: np.round(x,4)))

# %%
df_combined = (df_fut_rtn
    .rename(columns = {"security": "fut_ticker"})
    .assign(
        date       = lambda x: pd.to_datetime(x.date),
        fut_ticker = lambda x: x.fut_ticker + "1 Curncy")
    .merge(right = df_ticker_guide, how = "inner", on = ["fut_ticker"])
    .assign(etf_ticker = lambda x: x.etf_ticker.str.split(" ").str[0])
    .merge(right = df_signal, how = "inner", on = ["date", "etf_ticker"]))

# %%
def _get_resid(df: pd.DataFrame) -> pd.DataFrame: 

    df_out = (sm.OLS(
        endog = df.fut_rtn,
        exog  = sm.add_constant(df.signal)).
        fit().
        resid.
        to_frame(name = "resid").
        assign(
            lag_resid = lambda x: x.resid.shift(),
            decile    = lambda x: pd.qcut(x = x.resid, q = 10, labels = [i + 1 for i in range(10)]).shift()).
        dropna().
        merge(right = df, how = "inner", on = ["date"]))

    return df_out

df_ols = (df_combined.assign(
    group_var = lambda x: x.fut_ticker + " " + x.etf_ticker).
    set_index("date").
    groupby("group_var").
    apply(_get_resid, include_groups = False).
    reset_index().
    assign(signal_rtn = lambda x: -np.sign(x.lag_resid) * x.fut_rtn))

# %%
df_lagged = (df_ols.pivot(
    index = "date", columns = "fut_ticker", values = "signal_rtn").
    apply(lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std().shift() * np.sqrt(252)))).
    reset_index().
    melt(id_vars = "date", value_name = "rtn").
    assign(group = "lagged"))

# %%
df_perf = (df_ols.pivot(
    index = "date", columns = "fut_ticker", values = "signal_rtn").
    apply(lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std() * np.sqrt(252)))).
    reset_index().
    melt(id_vars = "date", value_name = "rtn").
    assign(group = "perfect"))

# %%
df_combined = (pd.concat([df_perf, df_lagged]))

# %%
group_vars = df_combined.group.drop_duplicates().sort_values().to_list()
fig, axes  = plt.subplots(ncols = len(group_vars), figsize = (20,6))

for group_var, ax in zip(group_vars, axes.flatten()):

    (df_combined.query(
        "group == @group_var").
        rename(columns = {"fut_ticker": ""}).
        pivot(index = "date", columns = "", values = "rtn").
        apply(lambda x: np.cumprod(1 + x)).
        plot(
            ax = ax,
            ylabel = "Cuml. Ret. Log-Scaled",
            title  = group_var.capitalize() + " Volatility Targetting"))

fig.suptitle("Cumulative Returns of Trading OLS Resids of Z-Scores\n10% Volatility Targetting from {} to {}".format(
    df_combined.date.min().year,
    df_combined.date.max().year))

plt.tight_layout()

# %% [markdown]
# # Trading Residuals Deciles

# %% [markdown]
# Now using the same approach as before decile the residuals and then trade the outer deciles if they have the same sign sharpe.

# %%
df_decile_sharpe = (df_ols[
    ["fut_ticker", "decile", "fut_rtn"]].
    groupby(["fut_ticker", "decile"]).
    agg(lambda x: x.mean() / x.std() * np.sqrt(252)).
    reset_index().
    rename(columns = {"fut_rtn": "sharpe"}))

# %%
df_decile_tmp = (df_decile_sharpe.query(
    "decile == [1,2,9,10]").
    assign(group = lambda x: np.where(x.decile <= 2, "lgroup", "ugroup")))

# %%
df_opt_rtn = (df_decile_tmp.drop(
    columns = ["decile"]).
    groupby(["fut_ticker", "group"]).
    agg("prod").
    reset_index().
    assign(signal_scaler = lambda x: np.where(x.sharpe > 0, 1, 0)).
    drop(columns = ["sharpe"]).
    merge(right = df_decile_tmp, how = "outer", on = ["fut_ticker", "group"]).
    merge(right = df_ols, how = "inner", on = ["fut_ticker", "decile"]).
    assign(signal_rtn = lambda x: np.sign(x.sharpe * x.signal_scaler) * x.fut_rtn))

# %%
df_lagged = (df_opt_rtn.pivot(
    index = "date", columns = "fut_ticker", values = "signal_rtn").
    apply(lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std().shift() * np.sqrt(252)))).
    apply(lambda x: np.where(np.abs(x) == np.inf, np.nan, x)).
    reset_index().
    melt(id_vars = "date", value_name = "rtn").
    assign(group = "lagged"))

df_perf = (df_opt_rtn.pivot(
    index = "date", columns = "fut_ticker", values = "signal_rtn").
    apply(lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std() * np.sqrt(252)))).
    apply(lambda x: np.where(np.abs(x) == np.inf, np.nan, x)).
    reset_index().
    melt(id_vars = "date", value_name = "rtn").
    assign(group = "perfect"))

# %%
df_combined = pd.concat([df_lagged, df_perf])

# %%
group_vars = df_combined.group.drop_duplicates().sort_values().to_list()
fig, axes  = plt.subplots(ncols = len(group_vars), figsize = (20,6))

for group_var, ax in zip(group_vars, axes.flatten()):

    (df_combined
        .loc[lambda x: x.group == group_var]
        .rename(columns = {"fut_ticker": ""})
        .pivot(index = "date", columns = "", values = "rtn")
        .fillna(0)
        .apply(lambda x: np.cumprod(1 + x))
        .plot(
            ax     = ax,
            ylabel = "Cuml. Ret. Log-Scaled",
            title  = group_var.capitalize() + " Volatility Targetting"))

fig.suptitle("Cumulative Returns of Trading OLS Resids of Z-Scores\n10% Volatility Targetting from {} to {}".format(
    df_combined.date.min().year,
    df_combined.date.max().year))

plt.tight_layout()

# %%
display(df_combined.rename(
    columns = {"rtn": "adj_rtn"}).
    assign(raw_rtn = lambda x: np.where(x.adj_rtn != x.adj_rtn, 0, x.adj_rtn)).
    melt(id_vars = ["date", "fut_ticker", "group"]).
    dropna().
    drop(columns = ["date"]).
    groupby(["fut_ticker", "group", "variable"]).
    agg(lambda x: x.mean() / x.std() * np.sqrt(252)).
    reset_index().
    assign(group = lambda x: x.group.str.capitalize()).
    rename(columns = {
        "group"     : "Vol. Target",
        "variable"  : "",
        "fut_ticker": "Future"}).
    replace({
        "adj_rtn": "Adj Sharpe",
        "raw_rtn": "Raw Sharpe"}).
    pivot(index = "Future", columns = ["Vol. Target", ""], values = "value").
    apply(lambda x: np.round(x,3)))

# %%
group_vars = df_combined.group.drop_duplicates().sort_values().to_list()
fig, axes  = plt.subplots(ncols = len(group_vars), figsize = (20,6))

for group_var, ax in zip(group_vars, axes.flatten()):

    df_corr = (df_combined.query(
        "group == @group_var").
        dropna().
        rename(columns = {"fut_ticker": ""}).
        pivot(index = "date", columns = "", values = "rtn").
        corr())

    sns.heatmap(
        data  = df_corr,
        ax    = ax,
        cbar  = False,
        annot = True)

    ax.set_title(group_var.capitalize() + " Volatility Targetting")

fig.suptitle("Correlations of Returns Trading OLS Resids of Z-Scores\n10% Volatility Targetting from {} to {}".format(
    df_combined.date.min().year,
    df_combined.date.max().year))

plt.tight_layout()

# %%
df_resid_port = (df_combined.drop(
    columns = ["fut_ticker"]).
    dropna().
    groupby(["date", "group"]).
    agg("mean").
    reset_index())

# %%
fig, axes = plt.subplots(figsize = (8,5))

(df_resid_port.assign(
    group = lambda x: x.group.str.capitalize()).
    rename(columns = {"group": ""}).
    pivot(index = "date", columns = "", values = "rtn").
    apply(lambda x: np.cumprod(1 + x)).
    plot(
        ax      = axes,
        logy    = True,
        ylabel  = "Cuml. Ret. Log-Scaled",
        title   = "Cumulative Returns of Trading FX Futures from Optimized OLS Residuals\n10% Volatility Targetting from {} to {}".format(
            df_resid_port.date.min().year,
            df_resid_port.date.max().year)))

plt.tight_layout()

# %%
display(df_resid_port.pivot(
    index = "date", columns = "group", values = "rtn").
    fillna(0).
    reset_index().
    melt(id_vars = "date", value_name = "raw_rtn").
    assign(adj_rtn = lambda x: np.where(x.raw_rtn != 0, x.raw_rtn, np.nan)).
    melt(id_vars = ["date", "group"]).
    dropna().
    drop(columns = ["date"]).
    groupby(["group", "variable"]).
    agg(lambda x: x.mean() / x.std() * np.sqrt(252)).
    reset_index().
    assign(group = lambda x: x.group.str.capitalize()).
    rename(columns = {"variable": ""}).
    pivot(index = "group", columns = "", values = "value").
    apply(lambda x: np.round(x,3)).
    rename(columns = {
        "adj_rtn": "Adj Sharpe",
        "raw_rtn": "Raw Rtn"}))

# %% [markdown]
# # Combining Portfolios

# %%
df_combined = (df_resid_port.rename(columns = {
    "group": "vol_group",
    "rtn"  : "resid_rtn"}).
    merge(right = df_zscore_port, how = "inner", on = ["date", "vol_group"]).
    rename(columns = {"rtn": "zscore_rtn"}))

# %%
(df_combined.drop(
    columns = ["date"]).
    groupby("vol_group").
    agg("corr").
    reset_index().
    query("resid_rtn != 1").
    assign(vol_group = lambda x: x.vol_group.str.capitalize()).
    rename(columns = {"vol_group": "Vol. Target"}).
    set_index("Vol. Target")
    [["resid_rtn"]].
    rename(columns = {"resid_rtn": "Correlation"}).
    apply(lambda x: np.round(x,3)))

# %%
df_combo_port = (df_combined.set_index([
    "date", "vol_group"]).
    assign(combined = lambda x: x.mean(axis = 1)).
    reset_index().
    melt(id_vars = ["date", "vol_group"]))

# %%
groups = df_combo_port.vol_group.drop_duplicates().sort_values().to_list()
fig, axes = plt.subplots(ncols = len(groups), figsize = (20,5))

renamer = {
    "combined"  : "Combo",
    "resid_rtn" : "Resid Port",
    "zscore_rtn": "Z-Score Port"}

for group, ax in zip(groups, axes.flatten()):

    (df_combo_port.query(
        "vol_group == @group").
        rename(columns = {"variable": ""}).
        pivot(index = "date", columns = "", values = "value").
        apply(lambda x: np.cumprod(1 + x)).
        rename(columns = renamer).
        plot(
            logy   = True,
            ax     = ax,
            ylabel = "Cuml. Ret. Log-Scaled",
            title  = group.capitalize() + " Volatility Targetting"))

fig.suptitle("Cumulative Returns of Combo Portfolio across optimized strategies\n10% Volatility Targetting From {} to {}".format(
    df_combo_port.date.min().year,
    df_combo_port.date.max().year))

plt.tight_layout()

# %%
display(df_combo_port.assign(
    adj_val = lambda x: np.where(x.value != 0, x.value, np.nan)).
    rename(columns = {
        "variable": "port",
        "value"   : "raw_val"}).
    melt(id_vars = ["date", "vol_group", "port"]).
    drop(columns = ["date"]).
    groupby(["vol_group", "port", "variable"]).
    agg(lambda x: x.mean() / x.std() * np.sqrt(252)).
    reset_index().
    assign(vol_group = lambda x: x.vol_group.str.capitalize()).
    rename(columns = {
        "variable" : "",
        "vol_group": "Vol. Target",
        "port"     : "Strategy"}).
    replace({
        "adj_val"   : "Adj Sharpe",
        "raw_val"   : "Raw Sharpe",
        "combined"  : "Combo",
        "resid_rtn" : "Resid Port",
        "zscore_rtn": "Z-Score Port"}).
    pivot(index = ["Strategy", "Vol. Target"], columns = "", values = "value").
    apply(lambda x: np.round(x,3)).
    reset_index().
    set_index("Strategy"))

# %% [markdown]
# # Trading Illiquid FX Futures

# %% [markdown]
# Previously illiquid futures were held out before liquid future returns have been verified. Since the results are reasonable its fair to add those futures in as well.

# %%
df_ill_ticker_guide = (pd
    .read_excel(io = guide_path)
    .loc[lambda x: x.group == "illiquid_future"]
    .drop(columns = ["group"])
    .rename(columns = {"ticker" : "fut_ticker"})
    .dropna())

# %%
df_ill_combined = (df_fut_rtn
    .rename(columns = {"security": "fut_ticker"})
    .assign(fut_ticker = lambda x: x.fut_ticker + "1 Curncy")
    .merge(right = df_ill_ticker_guide, how = "inner", on = ["fut_ticker"])
    .assign(
        date       = lambda x: pd.to_datetime(x.date),
        etf_ticker = lambda x: x.etf_ticker.str.split(" ").str[0])
    .merge(right = df_signal, how = "inner", on = ["date", "etf_ticker"]))

# %%
df_ill_zscore = (df_ill_combined.assign(
    signal_rtn = lambda x: -np.sign(x.signal) * x.fut_rtn))

# %%
df_ill_lagged = (df_ill_zscore.pivot(
    index = "date", columns = "fut_ticker", values = "signal_rtn").
    apply(lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std().shift() * np.sqrt(252)))).
    reset_index().
    melt(id_vars = "date", value_name = "rtn").
    assign(group = "lagged").
    dropna())

# %%
df_ill_perf = (df_ill_zscore.pivot(
    index = "date", columns = "fut_ticker", values = "signal_rtn").
    apply(lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std() * np.sqrt(252)))).
    reset_index().
    melt(id_vars = "date", value_name = "rtn").
    assign(group = "perfect").
    dropna())

# %%
df_ill_combined = (pd.concat([
    df_ill_lagged, df_ill_perf]))

# %%
fig, axes = plt.subplots(ncols = 2, figsize = (20,6))

(df_ill_combined.query(
    "group == 'perfect'").
    rename(columns = {"fut_ticker": ""}).
    pivot(index = "date", columns = "", values = "rtn").
    apply(lambda x: np.cumprod(1 +x)).
    plot(
        logy  = True,
        ax    = axes[0],
        title = "Illiquid Futures"))

(df_raw_zscore_combined.query(
    "group == 'perf'").
    rename(columns = {"fut_ticker": ""}).
    pivot(index = "date", columns = "", values = "rtn").
    apply(lambda x: np.cumprod(1 + x)).
    plot(
        logy  = True,
        ax    = axes[1],
        title = "Liquid Futures"))

fig.suptitle("Results of Trading Liquid and Illiquid Futures using 30d EWMA Z-Score of Equity Differential\n10% Volatility Target (Contemporaneously) From {} to {}".format(
    df_raw_zscore_combined.date.min(),
    df_raw_zscore_combined.date.max()))

for ax in axes.flatten():
    ax.set_ylabel("Cuml. Ret. Log-Scaled")

plt.tight_layout()

# %%
df_ill_decile_prep = (df_decile
    .assign(etf_ticker = lambda x: x.etf_ticker + " US Equity")
    .merge(right = df_ill_ticker_guide, how = "inner", on = ["etf_ticker"])
    .assign(
        date     = lambda x: pd.to_datetime(x.date),
        security = lambda x: x.fut_ticker.str.split("1").str[0])
    .merge(right = df_fut_rtn, how = "inner", on = ["date", "security"])
    .drop(columns = ["fut_ticker"])
    .rename(columns = {"security": "fut_ticker"}))

# %%
df_ill_decile = (df_ill_decile_prep[
    ["fut_ticker", "decile", "fut_rtn"]].
    groupby(["fut_ticker", "decile"]).
    agg(lambda x: x.mean() / x.std() * np.sqrt(252)).
    reset_index())

# %%
df_ill_decile_tmp = (df_ill_decile.query(
    "decile == [1,2,9,10]").
    assign(decile_group = lambda x: np.where(x.decile <= 2, "lgroup", "ugroup")))

# %%
df_ill_opt_rtn = (df_ill_decile_tmp[
    ["decile_group", "fut_ticker", "fut_rtn"]].
    groupby(["decile_group", "fut_ticker"]).
    agg("prod").
    assign(signal_scaler = lambda x: np.where(x.fut_rtn > 0, 1, np.nan)).
    reset_index().
    drop(columns = ["fut_rtn"]).
    merge(right = df_ill_decile_tmp, how = "outer", on = ["fut_ticker", "decile_group"]).
    rename(columns = {"fut_rtn": "sharpe"}).
    merge(right = df_ill_decile_prep, how = "inner", on = ["fut_ticker", "decile"]).
    assign(signal_rtn = lambda x: np.sign(x.signal_scaler * x.sharpe) * x.fut_rtn))

# %%
df_lagged = (df_ill_opt_rtn.pivot(
    index = "date", columns = "fut_ticker", values = "signal_rtn").
    apply(lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std().shift() * np.sqrt(252)))).
    reset_index().
    melt(id_vars = "date", value_name = "signal_rtn").
    assign(group = "lagged"))

# %%
df_perfect = (df_ill_opt_rtn.pivot(
    index = "date", columns = "fut_ticker", values = "signal_rtn").
    apply(lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std() * np.sqrt(252)))).
    reset_index().
    melt(id_vars = "date", value_name = "signal_rtn").
    assign(group = "perfect"))

# %%
df_ill_signal_rtn = pd.concat([df_lagged, df_perfect])

# %%
fig, axes = plt.subplots(ncols = 2, figsize = (20,6))

(df_ill_signal_rtn.query(
    "group == 'perfect'").
    rename(columns = {"fut_ticker": ""}).
    dropna().
    pivot(index = "date", columns = "", values = "signal_rtn").
    fillna(0).
    apply(lambda x: np.cumprod(1 +x)).
    plot(
        logy  = True,
        ax    = axes[0],
        title = "Liquid Futures"))

(df_sig_rtn.query(
    "vol_group == 'perfect'").
    rename(columns = {"fut_ticker": ""}).
    pivot(index = "date", columns = "", values = "rtn").
    fillna(0).
    apply(lambda x: np.cumprod(1 + x)).
    plot(
        logy  = True,
        ax    = axes[1],
        title = "Illiquid Futures"))

fig.suptitle("Results of Trading Liquid and Illiquid Futures using 30d EWMA Z-Score of Equity Differential\n10% Volatility Target (Contemporaneously) From {} to {}".format(
    df_sig_rtn.date.min(),
    df_sig_rtn.date.max()))

for ax in axes.flatten():
    ax.set_ylabel("Cuml. Ret. Log-Scaled")

plt.tight_layout()

# %%
df_liquid_port = (df_sig_rtn.query(
    "vol_group == 'perfect'")
    [["date", "rtn"]].
    groupby("date").
    agg("mean").
    fillna(0).
    rename(columns = {"rtn": "liquid"}))

# %%
df_illiquid_port = (df_ill_signal_rtn.query(
    "group == 'perfect'")
    [["date", "signal_rtn"]].
    groupby("date").
    agg("mean").
    rename(columns = {"signal_rtn": "illiquid"}).
    reset_index().
    fillna(0).
    assign(date = lambda x: pd.to_datetime(x.date)))

# %%
df_combo_port = (df_liquid_port.merge(
    right = df_illiquid_port, how = "outer", on = ["date"]).
    set_index("date"))

# %%
df_combo_port.corr()

# %%
df_combo_port.dropna().apply(lambda x: np.cumprod(1 + x)).plot(logy = True)
