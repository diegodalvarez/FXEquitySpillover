# %% [markdown]
# # Optimized Signal Backtest

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from   matplotlib.lines import Line2D

# %%
note_path = os.getcwd()
repo_path = os.path.abspath(os.path.join(note_path, ".."))
data_path = os.path.join(repo_path, "data")

# %%
group_mapper = {
    'em_carry'       : "EM Carry", 
    'g10_carry'      : "G10 Carry", 
    'illiquid_future': "Illiquid Fut", 
    'liquid_future'  : "Liquid Fut", 
    'full'           : "Full Portfolio"}

title_renamer = {
    "in_sample"         : "In-Sample",
    "out_sample"        : "Out-Sample",
    "ReturnSpreadSignal": "ETF Returns Differential",
    "ReturnsSignal"     : "ETF Returns"}

RENAMER = {**group_mapper, **title_renamer}

# %% [markdown]
# # Getting Raw Backtest

# %%
back_path = os.path.join(data_path, "Backtests")
df_rtn    = pd.read_parquet(path = back_path, engine = "pyarrow")

# %%
df_plot = (df_rtn
    .loc[lambda x: x.target == "lagged"]
    .drop(columns = ["target"])
    .assign(name = lambda x: x.signal_name + " " + x.sample_group))

# %%
color_map = {
    'em_carry'       : "green", 
    'g10_carry'      : "red", 
    'illiquid_future': "skyblue", 
    'liquid_future'  : "black", 
    'full'           : "orange"}


df_plot_guide = (df_plot
    .drop(columns = ["date", "rtn"])
    .drop_duplicates()
    .assign(
        color     = lambda x: x.portfolio.map(color_map),
        plot_name = lambda x: x.portfolio + " " + x.signal_type))

portfolio_handles = [
    Line2D(
        [0], [0],
        color=color,
        lw=2,
        label=group_mapper[portfolio]
    )
    for portfolio, color in color_map.items()
]

# %%
groups     = df_plot.name.drop_duplicates().sort_values().to_list()
plot_names = df_plot_guide.portfolio.drop_duplicates().sort_values().to_list()
fig, axes  = plt.subplots(ncols = len(groups) // 2, nrows = len(groups) // 2, figsize = (15,8))

for group, ax in zip(groups, axes.flatten()): 

    for plot in plot_names: 

        signal_name, sample = group.split(" ")

        port              = plot.split(" ")[0]
        df_plot_guide_tmp = (df_plot_guide
            .loc[lambda x: (x.name == group) & (x.portfolio == port)])

        strats = df_plot_guide_tmp.plot_name.to_list()
        color  = df_plot_guide_tmp.color.drop_duplicates().item()
        
        (df_plot
            .loc[lambda x: x.name == group]
            .assign(plot_name = lambda x: x.portfolio + " " + x.signal_type)
            .loc[lambda x: x.plot_name.isin(strats)]
            .pivot(index = "date", columns = "plot_name", values = "rtn")
            .fillna(0)
            .apply(lambda x: np.cumprod(1 + x))
            .plot(
                ax     = ax, 
                color  = color,
                logy   = True,
                alpha  = 0.8,
                legend = False,
                ylabel = "Cuml. Ret. Log-Scaled"))

    ax.set_title(signal_name + " " +  sample)
    ax.legend(handles = portfolio_handles)
    
plt.tight_layout()

# %%
group_cols = df_rtn.select_dtypes(include = "str").columns.to_list()

(df_rtn
    .drop(columns = ["date"])
    .groupby(group_cols)
    .agg(lambda x: x.mean() / x.std() * np.sqrt(252))
    .reset_index()
    
    .pivot(index = ["portfolio", "signal_name", "signal_type"], columns = ["target", "sample_group"], values = "rtn"))
# Out:
# target                                            lagged              perfect  \
# sample_group                                   in_sample out_sample in_sample
# portfolio       signal_name        signal_type
# em_carry        ReturnSpreadSignal perf_rtn     1.576336   1.387143  1.656846
#                                    px_rtn       1.975725   1.686295  2.116497
#                 ReturnsSignal      perf_rtn     2.619211   2.528253  2.846028
#                                    px_rtn       3.069455   2.580093  3.256786
# full            ReturnSpreadSignal perf_rtn     1.682317   1.242616  1.746319
#                                    px_rtn       2.116812   1.671846  2.213639
#                 ReturnsSignal      perf_rtn     2.486357   2.455368  2.635689
#                                    px_rtn       2.683924   2.434048  2.780535
# g10_carry       ReturnSpreadSignal perf_rtn     0.720785   0.368231  0.734950
#                                    px_rtn       0.775008   0.455289  0.796507
#                 ReturnsSignal      perf_rtn     0.875726   0.337515  0.860688
#                                    px_rtn       0.864239   0.584409  0.855675
# illiquid_future ReturnSpreadSignal perf_rtn     1.124983   0.667932  1.150093
#                                    px_rtn       1.161465   1.262274  1.159548
#                 ReturnsSignal      perf_rtn     2.198318   2.248270  2.247710
#                                    px_rtn       2.214307   2.043821  2.234762
# liquid_future   ReturnSpreadSignal perf_rtn     0.860690   0.511135  0.896644
#                                    px_rtn       1.015241   0.634616  1.009368
#                 ReturnsSignal      perf_rtn     1.307913   1.189201  1.318650
#                                    px_rtn       1.481595   1.199191  1.521890
#
# target
# sample_group                                   out_sample
# portfolio       signal_name        signal_type
# em_carry        ReturnSpreadSignal perf_rtn      1.468219
#                                    px_rtn        1.875588
#                 ReturnsSignal      perf_rtn      2.786992
#                                    px_rtn        2.905537
# full            ReturnSpreadSignal perf_rtn      1.354050
#                                    px_rtn        1.814373
#                 ReturnsSignal      perf_rtn      2.587772
#                                    px_rtn        2.651811
# g10_carry       ReturnSpreadSignal perf_rtn      0.381976
#                                    px_rtn        0.477719
#                 ReturnsSignal      perf_rtn      0.365815
#                                    px_rtn        0.558452
# illiquid_future ReturnSpreadSignal perf_rtn      0.546039
#                                    px_rtn        1.335664
#                 ReturnsSignal      perf_rtn      2.359444
#                                    px_rtn        2.139705
# liquid_future   ReturnSpreadSignal perf_rtn      0.659784
#                                    px_rtn        0.770725
#                 ReturnsSignal      perf_rtn      1.235686
#                                    px_rtn        1.235168
