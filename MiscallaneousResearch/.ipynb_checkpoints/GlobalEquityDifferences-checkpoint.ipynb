# %%
import os

# %%
cols = ['Trade Date','Strike','Expiry Date','Call/Put','Last Trade Price','Bid Price','Ask Price','Bid Implied Volatility','Ask Implied Volatility','Open Interest','Volume','Delta','Gamma','Vega','Theta','Rho']

# %%
import zipfile
import pandas as pd

zip_path = r"G:\FirstRateData\OptionsData\options_{}_q1.zip".format(year)

with zipfile.ZipFile(zip_path) as z:
    with z.open("EC_2022_q1_option_chain.txt") as f:
        df = pd.read_csv(
            filepath_or_buffer = f,
            header             = None,
            names              = cols)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 7
#       4 zip_path = r"G:\FirstRateData\OptionsData\options_2010_q1.zip"
#       6 with zipfile.ZipFile(zip_path) as z:
# ----> 7     with z.open("EC_2022_q1_option_chain.txt") as f:
#       8         df = pd.read_csv(
#       9             filepath_or_buffer = f,
#      10             header             = None,
#      11             names              = cols)
#
# File ~\anaconda3\Lib\zipfile\__init__.py:1639, in ZipFile.open(self, name, mode, pwd, force_zip64)
#    1636     zinfo.compress_level = self.compresslevel
#    1637 else:
#    1638     # Get info object for name
# -> 1639     zinfo = self.getinfo(name)
#    1641 if mode == 'w':
#    1642     return self._open_to_write(zinfo, force_zip64=force_zip64)
#
# File ~\anaconda3\Lib\zipfile\__init__.py:1567, in ZipFile.getinfo(self, name)
# ...

# %%
df
# Out:
#       Trade Date  Strike Expiry Date Call/Put  Last Trade Price  Bid Price  \
# 0     2010-01-04     150  2010-01-16        c             76.43       73.8
# 1     2010-01-04     160  2010-01-16        c             66.43       63.8
# 2     2010-01-04     170  2010-01-16        c             56.43       53.8
# 3     2010-01-04     180  2010-01-16        c             46.43       43.8
# 4     2010-01-04     190  2010-01-16        c             36.43       33.8
# ...          ...     ...         ...      ...               ...        ...
# 7339  2010-03-31     260  2010-09-18        p             33.43       37.0
# 7340  2010-03-31     270  2010-09-18        p             42.24       46.2
# 7341  2010-03-31     280  2010-09-18        p             51.61       55.8
# 7342  2010-03-31     290  2010-09-18        p             61.33       65.7
# 7343  2010-03-31     300  2010-09-18        p             71.22       75.6
#
#       Ask Price  Bid Implied Volatility  Ask Implied Volatility  \
# ...
